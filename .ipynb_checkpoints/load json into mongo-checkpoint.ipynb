# %%
import json
import os
import pymongo
import re
import yaml
import string

# %%
dir='/Users/katiebalcewicz/capstone-spring-2018-team-7/collect_data/android'
connection = pymongo.MongoClient("mongodb://localhost")
db = connection.apps
temp = db.temp
for filename in os.listdir(dir):
    filepath = dir+'/'+filename
    if not filename == "test_chart_2018-02-26.json":
        continue
    split = re.split('_|\.',filename)
    country = split[0]
    #print(country)
    chart = split[1]
    #print(chart)
    date = split[2]
    #print(date)
    data = open(filepath).read()
    data = data.replace("'","\"")
    data = data.replace("title:", "\"title\":")
    data = data.replace("summary:", "\"summary\":")
    data = data.replace("icon:", "\"icon\":")
    data = data.replace("price:", "\"price\":")
    data = data.replace("free:", "\"free\":")
    data = data.replace("minInstalls:", "\"minInstalls\":")
    data = data.replace("maxInstalls:", "\"maxInstalls\":")
    data = data.replace("score:", "\"score\":")
    data = data.replace("reviews:", "\"reviews\":")
    data = data.replace("developer:", "\"developer\":")
    data = data.replace("developerId:", "\"developerId\":")
    data = data.replace("developerEmail:", "\"developerEmail\":")
    data = data.replace("developerWebsite:", "\"developerWebsite\":")
    data = data.replace("developerAddress:", "\"developerAddress\":")
    data = data.replace("updated:", "\"updated\":")
    data = data.replace("version:", "\"version\":")
    data = data.replace("genre:", "\"genre\":")
    data = data.replace("genreId:", "\"genreId\":")
    data = data.replace("familyGenre:", "\"familyGenre\":")
    data = data.replace("familyGenreId:", "\"familyGenreId\":")
    data = data.replace("size:", "\"size\":")
    data = data.replace("description:", "\"description\":")
    data = data.replace("descriptionHTML:", "\"descriptionHTML\":")
    data = data.replace("histogram:", "\"histogram\":")
    data = data.replace("offersIAP:", "\"offersIAP\":")
    data = data.replace("adSupported:", "\"adSupported\":")
    data = data.replace("androidVersionText:", "\"androidVersionText\":")
    data = data.replace("androidVersion:", "\"androidVersion\":")
    data = data.replace("contentRating:", "\"contentRating\":")
    data = data.replace("screenshots:", "\"screenshots\":")
    data = data.replace("video:", "\"video\":")
    data = data.replace("comments:", "\"comments\":")
    data = data.replace("recentChanges:", "\"recentChanges\":")
    data = data.replace("preregister:", "\"preregister\":")
    data = data.replace("url:", "\"url\":")
    data = data.replace("appId:", "\"appId\":")
    data = data.replace("undefined", "\"undefined\"")
    print(data)
    obj=json.loads(data)
    print(obj)
    #print(json.dumps(data))
    #data = json_util.loads(data)
# Out:
# [
#  { "title": "Pixel Art - Color by Number Book",
#     "summary": "Pixel Art is a color by number game with lots of FREE pictures!",
#     "icon": "//lh3.googleusercontent.com/2OgBluK_z6NGKCVkVSWZSL6d2BZCQ_LunrTR-P1VkCOFi2jgtIj6lRTam4ossmq89dw=w300",
#     "price": "0",
#     "free": true,
#     "minInstalls": 10000000,
#     "maxInstalls": 50000000,
#     "score": 4.8,
#     "reviews": 495704,
#     "developer": "Easybrain",
#     "developerId": "7473634688510685864",
#     "developerEmail": "support@easybrain.com",
#     "developerWebsite": "http://www.easybrain.com",
#     "developerAddress": "3 Krinou street\nThe Oval, Office 701\nLimassol 4103\nCyprus",
#     "updated": "December 30, 2017",
#     "version": "2.1.2",
#     "genre": "Puzzle",
#     "genreId": "GAME_PUZZLE",
#     "familyGenre": "undefined",
#     "familyGenreId": "undefined",
#     "size": "undefined",
# ...

# %%
dir='/Users/katiebalcewicz/capstone-spring-2018-team-7/collect_data/android'
connection = pymongo.MongoClient("mongodb://localhost")
db = connection.apps
temp = db.temp
for filename in os.listdir(dir):
    filepath = dir+'/'+filename
    if not filename == "test_chart_2018-02-26.json":
        continue
    split = re.split('_|\.',filename)
    country = split[0]
    #print(country)
    chart = split[1]
    #print(chart)
    date = split[2]
    #print(date)
    data = open(filepath).read()
    data = ''.join(c for c in data if c in string.printable)
    #print(data)
    obj = yaml.load(data)
    print(obj)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-67ca33bb6d31> in <module>()
#      17     data = ''.join(c for c in data if c in string.printable)
#      18     #print(data)
# ---> 19     obj = yaml.load(data)
#      20     print(obj)
#
# /Users/katiebalcewicz/anaconda/lib/python3.6/site-packages/yaml/__init__.py in load(stream, Loader)
#      70     loader = Loader(stream)
#      71     try:
# ---> 72         return loader.get_single_data()
#      73     finally:
#      74         loader.dispose()
#
# /Users/katiebalcewicz/anaconda/lib/python3.6/site-packages/yaml/constructor.py in get_single_data(self)
#      33     def get_single_data(self):
#      34         # Ensure that the stream contains a single document and construct it.
# ---> 35         node = self.get_single_node()
#      36         if node is not None:
# ...
